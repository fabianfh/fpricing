# %%
# import the used libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import QuantLib as ql
import BootStrap.BootStrapping as bs
import MarketData.MarketData as md
import  math
#import MarketData.ReadExcel 
#import openpyxl 
import re

# %matplotlib inline

# %%
# Setting evaluation date
today = ql.Date.todaysDate()
#today = ql.TARGET().adjust(today,ql.Following)

ql.Settings.instance().setEvaluationDate(today)

# %%
mc = md.MarketConventions()
mdata = md.getBBMarketData()


oisZeroYields = bs.BootstrapOIS(mdata,mc)
discountTermStructure = ql.RelinkableYieldTermStructureHandle()
discountTermStructure.linkTo(oisZeroYields)
forecastTermStructure = ql.RelinkableYieldTermStructureHandle()
forecastTermStructure.linkTo(oisZeroYields)

# %%
# Assuming mc is an object with calendar and fixedSwapConvention attributes
start_date = mc.calendar.advance(today, ql.Period(2, ql.Days), mc.fixedSwapConvention)

maturity_date = mc.calendar.advance(start_date, ql.Period(10, ql.Years), mc.fixedSwapConvention)

freq = ql.Monthly

# %%
def testLoan(start_date, maturity_date, freq):
    as_of_date = ql.Settings.instance().evaluationDate

    eonia_index = ql.Eonia(ql.YieldTermStructureHandle(oisZeroYields))
    libor3m_index = ql.Euribor3M(ql.YieldTermStructureHandle(oisZeroYields))


    spreaded_discount_curve = ql.ZeroSpreadedTermStructure(
    ql.YieldTermStructureHandle(oisZeroYields),
    ql.QuoteHandle(ql.SimpleQuote(0.01) )) # 1% credit spread

    bond_engine = ql.DiscountingBondEngine(ql.YieldTermStructureHandle(spreaded_discount_curve))

    optionlet_vol = ql.ConstantOptionletVolatility(
        0,
        ql.TARGET(),
        ql.ModifiedFollowing,
        0.1,
        ql.Actual360()
    )

    coupon_pricer = ql.BlackIborCouponPricer(ql.OptionletVolatilityStructureHandle(optionlet_vol))
    schedule = ql.Schedule(start_date, maturity_date, ql.Period(freq), mc.calendar,
                           ql.Unadjusted, ql.ModifiedFollowing, ql.DateGeneration.Forward, False)
    notional = 100000
    notional_schedule = [notional] * (len(schedule) - 1)



    gearings= [],
    spreads = [],
    caps = [0.05],
    floors = [0],

    floater = ql.AmortizingFloatingRateBond(mc.settlementDays, notional_schedule, schedule,
                                            libor3m_index, ql.Actual360(), ql.ModifiedFollowing,
                                            mc.settlementDays, [], [], [], [], True, as_of_date)
    
    


    




    floater.setPricingEngine(bond_engine)
    ql.setCouponPricer(floater.cashflows(), coupon_pricer)

    price = floater.NPV()
    print(f"NPV: {price}")

    #yr = floater.yield(ql.Actual360(), ql.Compounded, ql.Semiannual)
    #floater.duration(ql.Actual360(), yield_rate, ql.Compounded, ql.Semiannual, ql.Duration.Modified)
    #floater.convexity(ql.Actual360(), yield_rate, ql.Compounded, ql.Semiannual)

    
    # Extract cashflow data

    




    data = []
    for cf in floater.cashflows():
        row = {
            "Payment Date": cf.date().ISO(),
            "Amount": cf.amount(),
            "Accrual Start": None,
            "Accrual End": None,
            "Nominal": None,
            "Rate": None,
            "Spread": None,
            "Gearing": None
        }

        if ql.as_floating_rate_coupon(cf):
            frc = ql.as_floating_rate_coupon(cf)
            row.update({
                "Accrual Start": frc.accrualStartDate().ISO(),
                "Accrual End": frc.accrualEndDate().ISO(),
                "Nominal": frc.nominal(),
                "Rate": frc.rate(),
                "Spread": frc.spread(),
                "Gearing": frc.gearing()
            })
        elif ql.as_overnight_indexed_coupon(cf):
            oic = ql.as_overnight_indexed_coupon(cf)

            row.update({
                "Accrual Start": oic.accrualStartDate().ISO(),
                "Accrual End": oic.accrualEndDate().ISO(),
                "Nominal": oic.nominal(),
                "Rate": oic.rate(),
                "Spread": oic.spread(),
                "Gearing": oic.gearing()
            })
       

        data.append(row)


    # Create DataFrame
    df = pd.DataFrame(data)
    print(df)

# %%
testLoan(start_date,maturity_date,freq)
# Out:
# NPV: 90631.87068841388
#     Payment Date         Amount Accrual Start Accrual End   Nominal      Rate  \
# 0     2025-09-15      -8.218865    2025-08-14  2025-09-14  100000.0 -0.000954
# 1     2025-10-14      -8.856164    2025-09-14  2025-10-14  100000.0 -0.001063
# 2     2025-11-14     -10.214518    2025-10-14  2025-11-14  100000.0 -0.001186
# 3     2025-12-15     -10.584637    2025-11-14  2025-12-14  100000.0 -0.001270
# 4     2026-01-14     -11.500363    2025-12-14  2026-01-14  100000.0 -0.001336
# ..           ...            ...           ...         ...       ...       ...
# 116   2035-05-14      62.986436    2035-04-14  2035-05-14  100000.0  0.007558
# 117   2035-06-14      60.660250    2035-05-14  2035-06-14  100000.0  0.007044
# 118   2035-07-16      54.283006    2035-06-14  2035-07-14  100000.0  0.006514
# 119   2035-08-14      51.953483    2035-07-14  2035-08-14  100000.0  0.006033
# 120   2035-08-14  100000.000000          None        None       NaN       NaN
#
#      Spread  Gearing
# 0       0.0      1.0
# 1       0.0      1.0
# 2       0.0      1.0
# 3       0.0      1.0
# 4       0.0      1.0
# ..      ...      ...
# 116     0.0      1.0
# 117     0.0      1.0
# 118     0.0      1.0
# 119     0.0      1.0
# 120     NaN      NaN
#
# [121 rows x 8 columns]
# Cashflow 0: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 1: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 2: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 3: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 4: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 5: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 6: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 7: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 8: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 9: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 10: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 11: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 12: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 13: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 14: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 15: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 16: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 17: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 18: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 19: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 20: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 21: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 22: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 23: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 24: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 25: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 26: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 27: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 28: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 29: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 30: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 31: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 32: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 33: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 34: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 35: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 36: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 37: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 38: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 39: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 40: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 41: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 42: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 43: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 44: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 45: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 46: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 47: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 48: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 49: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 50: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 51: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 52: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 53: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 54: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 55: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 56: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 57: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 58: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 59: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 60: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 61: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 62: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 63: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 64: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 65: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 66: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 67: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 68: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 69: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 70: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 71: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 72: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 73: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 74: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 75: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 76: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 77: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 78: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 79: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 80: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 81: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 82: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 83: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 84: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 85: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 86: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 87: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 88: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 89: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 90: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 91: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 92: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 93: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 94: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 95: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 96: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 97: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 98: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 99: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 100: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 101: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 102: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 103: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 104: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 105: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 106: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 107: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 108: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 109: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 110: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 111: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 112: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 113: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 114: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 115: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 116: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 117: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 118: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 119: type = <class 'QuantLib.QuantLib.CashFlow'>
# Cashflow 120: type = <class 'QuantLib.QuantLib.CashFlow'>
